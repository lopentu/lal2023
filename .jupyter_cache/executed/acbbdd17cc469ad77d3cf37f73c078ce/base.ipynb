# %%
# imports
import os
import sys
import types
import json

# figure size/format
fig_width = 7
fig_height = 5
fig_format = 'retina'
fig_dpi = 96

# matplotlib defaults / format
try:
  import matplotlib.pyplot as plt
  plt.rcParams['figure.figsize'] = (fig_width, fig_height)
  plt.rcParams['figure.dpi'] = fig_dpi
  plt.rcParams['savefig.dpi'] = fig_dpi
  from IPython.display import set_matplotlib_formats
  set_matplotlib_formats(fig_format)
except Exception:
  pass

# plotly use connected mode
try:
  import plotly.io as pio
  pio.renderers.default = "notebook_connected"
except Exception:
  pass

# enable pandas latex repr when targeting pdfs
try:
  import pandas as pd
  if fig_format == 'pdf':
    pd.set_option('display.latex.repr', True)
except Exception:
  pass



# output kernel dependencies
kernel_deps = dict()
for module in list(sys.modules.values()):
  # Some modules play games with sys.modules (e.g. email/__init__.py
  # in the standard library), and occasionally this can cause strange
  # failures in getattr.  Just ignore anything that's not an ordinary
  # module.
  if not isinstance(module, types.ModuleType):
    continue
  path = getattr(module, "__file__", None)
  if not path:
    continue
  if path.endswith(".pyc") or path.endswith(".pyo"):
    path = path[:-1]
  if not os.path.exists(path):
    continue
  kernel_deps[path] = os.stat(path).st_mtime
print(json.dumps(kernel_deps))

# set run_path if requested
if r'/Users/shukai/Desktop/lal2023':
  os.chdir(r'/Users/shukai/Desktop/lal2023')

# reset state
# %reset

def ojs_define(**kwargs):
  import json
  try:
    # IPython 7.14 preferred import
    from IPython.display import display, HTML
  except:
    from IPython.core.display import display, HTML

  # do some minor magic for convenience when handling pandas
  # dataframes
  def convert(v):
    try:
      import pandas as pd
    except ModuleNotFoundError: # don't do the magic when pandas is not available
      return v
    if type(v) == pd.Series:
      v = pd.DataFrame(v)
    if type(v) == pd.DataFrame:
      j = json.loads(v.T.to_json(orient='split'))
      return dict((k,v) for (k,v) in zip(j["index"], j["data"]))
    else:
      return v
  
  v = dict(contents=list(dict(name=key, value=convert(value)) for (key, value) in kwargs.items()))
  display(HTML('<script type="ojs-define">' + json.dumps(v) + '</script>'), metadata=dict(ojs_define = True))
globals()["ojs_define"] = ojs_define
# Out:
# {"/Users/shukai/anaconda3/lib/python3.8/importlib/_bootstrap.py": 1599204247.0, "/Users/shukai/anaconda3/lib/python3.8/importlib/_bootstrap_external.py": 1599204247.0, "/Users/shukai/anaconda3/lib/python3.8/codecs.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/encodings/aliases.py": 1599204247.0, "/Users/shukai/anaconda3/lib/python3.8/encodings/__init__.py": 1599204247.0, "/Users/shukai/anaconda3/lib/python3.8/encodings/utf_8.py": 1599204247.0, "/Users/shukai/anaconda3/lib/python3.8/encodings/latin_1.py": 1599204247.0, "/Users/shukai/anaconda3/lib/python3.8/abc.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/io.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/stat.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/_collections_abc.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/genericpath.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/posixpath.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/os.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/_sitebuiltins.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/_bootlocale.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/types.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/warnings.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/importlib/__init__.py": 1599204247.0, "/Users/shukai/anaconda3/lib/python3.8/importlib/machinery.py": 1599204247.0, "/Users/shukai/anaconda3/lib/python3.8/importlib/abc.py": 1599204247.0, "/Users/shukai/anaconda3/lib/python3.8/operator.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/keyword.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/lib-dynload/_heapq.cpython-38-darwin.so": 1603418581.7571468, "/Users/shukai/anaconda3/lib/python3.8/heapq.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/reprlib.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/collections/__init__.py": 1599204247.0, "/Users/shukai/anaconda3/lib/python3.8/functools.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/contextlib.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/importlib/util.py": 1599204247.0, "/Users/shukai/anaconda3/lib/python3.8/site-packages/sphinxcontrib/__init__.py": 1573662689.0, "/Users/shukai/anaconda3/lib/python3.8/site-packages/zope/__init__.py": 1573662590.0, "/Users/shukai/anaconda3/lib/python3.8/site.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/_weakrefset.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/weakref.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/pkgutil.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/runpy.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/site-packages/ipykernel/_version.py": 1596206705.0, "/Users/shukai/anaconda3/lib/python3.8/__future__.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/enum.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/sre_constants.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/sre_parse.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/sre_compile.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/copyreg.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/re.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/lib-dynload/_json.cpython-38-darwin.so": 1603418581.7584052, "/Users/shukai/anaconda3/lib/python3.8/json/scanner.py": 1599204247.0, "/Users/shukai/anaconda3/lib/python3.8/json/decoder.py": 1599204247.0, "/Users/shukai/anaconda3/lib/python3.8/json/encoder.py": 1599204247.0, "/Users/shukai/anaconda3/lib/python3.8/json/__init__.py": 1599204247.0, "/Users/shukai/anaconda3/lib/python3.8/signal.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/threading.py": 1599204245.0, "/Users/shukai/anaconda3/lib/python3.8/lib-dynload/_posixsubprocess.cpython-38-darwin.so": 1603418581.7687583, "/Users/shukai/anaconda3/lib/python3.8/lib-dynload/select.cpython-38-darwin.so": 1603418581.8102646, "/Users/shukai/anaconda3/lib/python3.8/collections/ ...

# %%
import lingtypology
from pycldf import Dataset
import pandas as pd
pd.options.plotting.backend = "plotly"

# %%
data = pd.read_csv(
    'https://raw.githubusercontent.com/ropensci/lingtypology/master/database_creation/ejective_and_n_consonants.csv',
    delimiter=',',
    header=0,
)
m = lingtypology.LingMap(data.language)
m.legend_title = 'Consonants'
m.legend_position = 'bottomleft'
m.add_tooltips(data.consonants)
#If numeric is True, it will look like this
m.add_features(data.consonants, numeric=True)
m.create_map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48ad0b64120fc557c50e3d7a06133c1c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48ad0b64120fc557c50e3d7a06133c1c&quot; &gt;&lt;/div&gt;
#
#
# &lt;!-- Based on the template from here: https://nbviewer.jupyter.org/gist/talbertc-usgs/18f8901fc98f109f2b71156cf3ac81cd --&gt;
# &lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1&quot;&gt;
#   &lt;link rel=&quot;stylesheet&quot; href=&quot;//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css&quot;&gt;
#
#   &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.js&quot;&gt;&lt;/script&gt;
#   &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#
#   &lt;script&gt;
#     $(function(){
#         $(&quot;#maplegend0&quot;).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#   &lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div id=&#x27;maplegend0&#x27; class=&#x27;maplegend&#x27;
#     style=&#x27;position: absolute; z-index:9999; border:2px solid grey; background-color:rgba(255, 255, 255, 0.8);
#      border-radius:6px; padding: 10px; font-size:14px; left: 20px; bottom: 40px;&#x27;&gt;
#
#
# &lt;div class=&#x27;legend-title&#x27;&gt;Consonants&lt;/div&gt;
#
# &lt;div class=&#x27;legend-scale&#x27;&gt;
#   &lt;ul class=&#x27;legend-labels&#x27;&gt;
#
#     &lt;svg height=&quot;163&quot; width=&quot;20&quot;&gt;&lt;line x1=&quot;0&quot; y1=&quot;0&quot; x2=&quot;20&quot; y2=&quot;0&quot;style=&quot;stroke:#ffffffff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;2&quot; x2=&quot;20&quot; y2=&quot;2&quot;style=&quot;stroke:#fefffeff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;3&quot; x2=&quot;20&quot; y2=&quot;3&quot;style=&quot;stroke:#fdfefdff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;4&quot; x2=&quot;20&quot; y2=&quot;4&quot;style=&quot;stroke:#fcfefcff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;5&quot; x2=&quot;20&quot; y2=&quot;5&quot;style=&quot;stroke:#fafdfaff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;6&quot; x2=&quot;20&quot; y2=&quot;6&quot;style=&quot;stroke:#f9fcf9ff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;7&quot; x2=&quot;20&quot; y2=&quot;7&quot;style=&quot;stroke:#f8fcf8ff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;8&quot; x2=&quot;20&quot; y2=&quot;8&quot;style=&quot;stroke:#f7fbf7ff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;9&quot; x2=&quot;20&quot; y2=&quot;9&quot;style=&quot;stroke:#f5faf5ff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;10&quot; x2=&quot;20&quot; y2=&quot;10&quot;style=&quot;stroke:#f4faf4ff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;11&quot; x2=&quot;20&quot; y2=&quot;11&quot;style=&quot;stroke:#f3f9f3ff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;12&quot; x2=&quot;20&quot; y2=&quot;12&quot;style=&quot;stroke:#f1f8f1ff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;13&quot; x2=&quot;20&quot; y2=&quot;13&quot;style=&quot;stroke:#f0f8f0ff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;14&quot; x2=&quot;20&quot; y2=&quot;14&quot;style=&quot;stroke:#eff7efff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;15&quot; x2=&quot;20&quot; y2=&quot;15&quot;style=&quot;stroke:#eef7eeff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;16&quot; x2=&quot;20&quot; y2=&quot;16&quot;style=&quot;stroke:#ecf6ecff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;17&quot; x2=&quot;20&quot; y2=&quot;17&quot;style=&quot;stroke:#ebf5ebff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;18&quot; x2=&quot;20&quot; y2=&quot;18&quot;style=&quot;stroke:#eaf5eaff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;18&quot; x2=&quot;20&quot; y2=&quot;18&quot;style=&quot;stroke:#e6f3e6ff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;20&quot; x2=&quot;20&quot; y2=&quot;20&quot;style=&quot;stroke:#e5f2e5ff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;21&quot; x2=&quot;20&quot; y2=&quot;21&quot;style=&quot;stroke:#e3f1e3ff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;22&quot; x2=&quot;20&quot; y2=&quot;22&quot;style=&quot;stroke:#e2f1e2ff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;23&quot; x2=&quot;20&quot; y2=&quot;23&quot;style=&quot;stroke:#e1f0e1ff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;24&quot; x2=&quot;20&quot; y2=&quot;24&quot;style=&quot;stroke:#dff0dfff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;25&quot; x2=&quot;20&quot; y2=&quot;25&quot;style=&quot;stroke:#deefdeff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;26&quot; x2=&quot;20&quot; y2=&quot;26&quot;style=&quot;stroke:#ddeeddff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;27&quot; x2=&quot;20&quot; y2=&quot;27&quot;style=&quot;stroke:#dceedcff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1=&quot;28&quot; x2=&quot;20&quot; y2=&quot;28&quot;style=&quot;stroke:#daeddaff;stroke-width:3;&quot; /&gt;&lt;line x1=&quot;0&quot; y1
